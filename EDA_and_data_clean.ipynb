# %% [markdown]
# # Iris Dataset - EDA and Data Cleaning
# Basic exploratory data analysis and data cleaning checks on the Iris dataset.

# %%
# Import required library
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("Iris_try.csv")

# %%
# Preview the first 5 rows
df.head()

# %%
# Preview the last 5 rows
df.tail()

# %%
# Get column names, data types, and non-null counts
df.info()

# %%
# List all column names
df.columns

# %%
# Get summary statistics (mean, std, min, max, quartiles) for numeric columns
df.describe()

# %%
# Check for missing values in each column
df.isnull().sum()

# %%
# Check for duplicate rows
df.duplicated().sum()
